# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from ta.momentum import RSIIndicator

# Descargar datos de PETR4
dados = yf.download("PETR4.SA", start="2024-01-01")

# Calcular media móvil de 20 días
dados["Media_20"] = dados["Close"].rolling(window=20).mean()

# Calcular RSI (garantizando que sea una Serie 1D)
close_series = dados["Close"].copy().squeeze()
rsi_calc = RSIIndicator(close=close_series, window=14)
dados["RSI"] = rsi_calc.rsi()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(12, 6))
plt.plot(dados["Close"], label="Preço de Fechamento")
plt.plot(dados["Media_20"], label="Média Móvel 20 dias", linestyle="--")
plt.title("PETR4 - Análise com Média Móvel")
plt.xlabel("Data")
plt.ylabel("Preço (R$)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.plot(dados["RSI"], label="RSI 14 dias", color="purple")
plt.axhline(70, linestyle='--', color='red', label='Sobrecompra (70)')
plt.axhline(30, linestyle='--', color='green', label='Sobrevenda (30)')
plt.title("PETR4 - Índice de Força Relativa (RSI)")
plt.xlabel("Data")
plt.ylabel("RSI")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD

# Descargar datos de PETR4
dados = yf.download("PETR4.SA", start="2024-01-01")

# Resetar índice para evitar problemas con fechas
dados.reset_index(inplace=True)

# Médias móveis
dados["MM20"] = dados["Close"].rolling(window=20).mean()
dados["MM50"] = dados["Close"].rolling(window=50).mean()

# Calcular MACD
macd_calc = MACD(Close=dados["Close"])
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9612\2862688982.py in <module>
#      15
#      16 # Calcular MACD
# ---> 17 macd_calc = MACD(Close=dados["Close"])
#      18 dados["MACD"] = macd_calc.macd()
#      19 dados["MACD_Sinal"] = macd_calc.macd_signal()
#
# TypeError: __init__() got an unexpected keyword argument 'Close'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9612\3595595993.py in <module>
#       1 plt.figure(figsize=(12, 3))
# ----> 2 plt.bar(dados.index, dados["Volume"], color="gray")
#       3 plt.title("PETR4 - Volume negociado")
#       4 plt.xlabel("Data")
#       5 plt.ylabel("Volume")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2397         x, height, width=0.8, bottom=None, *, align='center',
#    2398         data=None, **kwargs):
# -> 2399     return gca().bar(
#    2400         x, height, width=width, bottom=bottom, align=align,
#    2401         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MACD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
macd_calc = MACD(
    close=dados["Close"], 
    window_slow=26, 
    window_fast=12, 
    window_sign=9
)

# %%
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9612\291211383.py in <module>
# ----> 1 dados["MACD"] = macd_calc.macd()
#       2 dados["MACD_Sinal"] = macd_calc.macd_signal()
#       3 dados["MACD_Histograma"] = macd_calc.macd_diff()
#
# ~\anaconda3\lib\site-packages\ta\trend.py in macd(self)
#     127         """
#     128         macd_series = self._check_fillna(self._macd, value=0)
# --> 129         return pd.Series(
#     130             macd_series, name=f"MACD_{self._window_fast}_{self._window_slow}"
#     131         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     365             name = ibase.maybe_extract_name(name, data, type(self))
#     366
# --> 367             if is_empty_data(data) and dtype is None:
#     368                 # gh-17261
# ...

# %%
dados["Close"].head()
# Out:
# Ticker   PETR4.SA
# 0       31.249472
# 1       32.225506
# 2       31.952545
# 3       32.026989
# 4       31.787119

# %%
from ta.trend import MACD

# Asegurarse de que Close es una Serie válida
close_prices = dados["Close"].dropna().reset_index(drop=True)

# Crear nuevo MACD con datos limpios
macd_calc = MACD(
    close=close_prices,
    window_slow=26,
    window_fast=12,
    window_sign=9
)

# Recortar datos y agregar al DataFrame original
dados = dados.iloc[-len(close_prices):].copy()
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9612\3360554898.py in <module>
#      14 # Recortar datos y agregar al DataFrame original
#      15 dados = dados.iloc[-len(close_prices):].copy()
# ---> 16 dados["MACD"] = macd_calc.macd()
#      17 dados["MACD_Sinal"] = macd_calc.macd_signal()
#      18 dados["MACD_Histograma"] = macd_calc.macd_diff()
#
# ~\anaconda3\lib\site-packages\ta\trend.py in macd(self)
#     127         """
#     128         macd_series = self._check_fillna(self._macd, value=0)
# --> 129         return pd.Series(
#     130             macd_series, name=f"MACD_{self._window_fast}_{self._window_slow}"
#     131         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     365             name = ibase.maybe_extract_name(name, data, type(self))
#     366
# ...

# %%
print(dados.columns)
# Out:
# MultiIndex([(  'Date',         ''),
#             ( 'Close', 'PETR4.SA'),
#             (  'High', 'PETR4.SA'),
#             (   'Low', 'PETR4.SA'),
#             (  'Open', 'PETR4.SA'),
#             ('Volume', 'PETR4.SA'),
#             (  'MM20',         ''),
#             (  'MM50',         '')],
#            names=['Price', 'Ticker'])

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD

# 🔹 Descargar datos de PETR4
dados = yf.download("PETR4.SA", start="2024-01-01")

# 🔹 Resetar índice para facilitar manipulación
dados.reset_index(inplace=True)

# 🔹 Eliminar MultiIndex de columnas (si existe)
dados.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in dados.columns]

# 🔹 Calcular médias móveis
dados["MM20"] = dados["Close_PETR4.SA"].rolling(window=20).mean()
dados["MM50"] = dados["Close_PETR4.SA"].rolling(window=50).mean()

# 🔹 Calcular MACD
close_prices = dados["Close_PETR4.SA"].dropna().reset_index(drop=True)

macd_calc = MACD(
    close=close_prices,
    window_slow=26,
    window_fast=12,
    window_sign=9
)

# 🔹 Ajustar DataFrame y agregar resultados
dados = dados.iloc[-len(close_prices):].copy()
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(12, 6))
plt.plot(dados["Date"], dados["Close_PETR4.SA"], label="Preço de Fechamento", color="black")
plt.plot(dados["Date"], dados["MM20"], label="Média Móvel 20", linestyle="--", color="blue")
plt.plot(dados["Date"], dados["MM50"], label="Média Móvel 50", linestyle="--", color="orange")
plt.title("PETR4 - Preço com Médias Móveis")
plt.xlabel("Data")
plt.ylabel("Preço (R$)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.figure(figsize=(12, 4))
plt.plot(dados["Date"], dados["MACD"], label="MACD", color="purple")
plt.plot(dados["Date"], dados["MACD_Sinal"], label="Linha de Sinal", color="red", linestyle="--")
plt.bar(dados["Date"], dados["MACD_Histograma"], label="Histograma", color="gray", alpha=0.4)
plt.title("PETR4 - MACD")
plt.xlabel("Data")
plt.ylabel("MACD")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(dados["Date_"], dados["Close_PETR4.SA"], label="Preço de Fechamento", color="black")
plt.plot(dados["Date_"], dados["MM20"], label="Média Móvel 20", linestyle="--", color="blue")
plt.plot(dados["Date_"], dados["MM50"], label="Média Móvel 50", linestyle="--", color="orange")
plt.title("PETR4 - Preço com Médias Móveis")
plt.xlabel("Data")
plt.ylabel("Preço (R$)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.plot(dados["Date_"], dados["MACD"], label="MACD", color="purple")
plt.plot(dados["Date_"], dados["MACD_Sinal"], label="Linha de Sinal", color="red", linestyle="--")
plt.bar(dados["Date_"], dados["MACD_Histograma"], label="Histograma", color="gray", alpha=0.4)
plt.title("PETR4 - MACD")
plt.xlabel("Data")
plt.ylabel("MACD")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.bar(dados["Date_"], dados["Volume_PETR4.SA"], color="gray", width=1)
plt.title("PETR4 - Volume Negociado")
plt.xlabel("Data")
plt.ylabel("Volume")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# !pip install ta

# %%
# Instalar si aún no lo tienes
# !pip install ta yfinance --quiet

# Importar bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD
import yfinance as yf

# Descargar datos desde Yahoo Finance
dados = yf.download("PETR4.SA", start="2024-01-01")
dados.reset_index(inplace=True)

# Limpiar columnas si es MultiIndex
dados.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in dados.columns]

# Calcular medias móviles
dados["MM20"] = dados["Close_PETR4.SA"].rolling(window=20).mean()
dados["MM50"] = dados["Close_PETR4.SA"].rolling(window=50).mean()

# Calcular MACD
close_prices = dados["Close_PETR4.SA"].dropna().reset_index(drop=True)
macd_calc = MACD(close=close_prices, window_slow=26, window_fast=12, window_sign=9)
dados = dados.iloc[-len(close_prices):].copy()
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()

# Señales de compra y venta (cruce MACD ↕️ Línea de señal)
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# 🎯 Gráfico final con señales
plt.figure(figsize=(14, 6))
plt.plot(dados["Date_"], dados["Close_PETR4.SA"], label="Preço", color="black")
plt.plot(dados["Date_"], dados["MM20"], label="MM20", linestyle="--", color="blue")
plt.plot(dados["Date_"], dados["MM50"], label="MM50", linestyle="--", color="orange")

# Agregar flechas de compra (verdes ↑) y venta (rojas ↓)
plt.scatter(dados.loc[dados["Compra"], "Date_"], dados.loc[dados["Compra"], "Close_PETR4.SA"],
            label="📈 Compra", marker="^", color="green", s=120)
plt.scatter(dados.loc[dados["Venda"], "Date_"], dados.loc[dados["Venda"], "Close_PETR4.SA"],
            label="📉 Venda", marker="v", color="red", s=120)

plt.title("PETR4 - Sinais de Compra e Venda com MACD")
plt.xlabel("Data")
plt.ylabel("Preço (R$)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\rodri\AppData\Local\Temp\ipykernel_9612\347487430.py:50: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   plt.tight_layout()
# C:\Users\rodri\AppData\Local\Temp\ipykernel_9612\347487430.py:50: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from current font.
#   plt.tight_layout()
# C:\Users\rodri\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rodri\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install ta requests pandas matplotlib --quiet

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.momentum import RSIIndicator
from ta.trend import MACD

# ✅ Tu API key
api_key = 'CW8ZHIC5A9DKYDVQ'

# ✅ Solicitar datos de USD/BRL en intervalo de 5 minutos
url = f'https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol=USD&to_symbol=BRL&interval=5min&apikey={api_key}&datatype=csv'
res = requests.get(url)

# ✅ Leer datos como DataFrame
dados = pd.read_csv(pd.compat.StringIO(res.text))
dados.rename(columns={'timestamp': 'Date'}, inplace=True)
dados["Date"] = pd.to_datetime(dados["Date"])
dados.sort_values("Date", inplace=True)

# ✅ Cálculo de indicadores técnicos
dados["MM20"] = dados["close"].rolling(window=20).mean()
dados["MM50"] = dados["close"].rolling(window=50).mean()
rsi = RSIIndicator(close=dados["close"], window=14)
dados["RSI"] = rsi.rsi()
macd = MACD(close=dados["close"])
dados["MACD"] = macd.macd()
dados["MACD_Sinal"] = macd.macd_signal()

# ✅ Señales de compra/venta (MACD)
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# ✅ Gráfico con flechas
plt.figure(figsize=(14, 6))
plt.plot(dados["Date"], dados["close"], label="Preço", color="black")
plt.plot(dados["Date"], dados["MM20"], label="MM20", linestyle="--", color="blue")
plt.plot(dados["Date"], dados["MM50"], label="MM50", linestyle="--", color="orange")

plt.scatter(dados.loc[dados["Compra"], "Date"], dados.loc[dados["Compra"], "close"],
            label="📈 Compra", marker="^", color="green", s=100)
plt.scatter(dados.loc[dados["Venda"], "Date"], dados.loc[dados["Venda"], "close"],
            label="📉 Venda", marker="v", color="red", s=100)

plt.title("USD/BRL - Sinais de Compra e Venda (Alpha Vantage)")
plt.xlabel("Data")
plt.ylabel("Preço")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9612\2194975088.py in <module>
#      13
#      14 # ✅ Leer datos como DataFrame
# ---> 15 dados = pd.read_csv(pd.compat.StringIO(res.text))
#      16 dados.rename(columns={'timestamp': 'Date'}, inplace=True)
#      17 dados["Date"] = pd.to_datetime(dados["Date"])
#
# AttributeError: module 'pandas.compat' has no attribute 'StringIO'

# %%
from io import StringIO

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.momentum import RSIIndicator
from ta.trend import MACD

# ✅ Tu API key
api_key = 'CW8ZHIC5A9DKYDVQ'

# ✅ Solicitar datos de USD/BRL en intervalo de 5 minutos
url = f'https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol=USD&to_symbol=BRL&interval=5min&apikey={api_key}&datatype=csv'
res = requests.get(url)

# ✅ Leer datos como DataFrame
dados = pd.read_csv(pd.compat.StringIO(res.text))
dados.rename(columns={'timestamp': 'Date'}, inplace=True)
dados["Date"] = pd.to_datetime(dados["Date"])
dados.sort_values("Date", inplace=True)

# ✅ Cálculo de indicadores técnicos
dados["MM20"] = dados["close"].rolling(window=20).mean()
dados["MM50"] = dados["close"].rolling(window=50).mean()
rsi = RSIIndicator(close=dados["close"], window=14)
dados["RSI"] = rsi.rsi()
macd = MACD(close=dados["close"])
dados["MACD"] = macd.macd()
dados["MACD_Sinal"] = macd.macd_signal()

# ✅ Señales de compra/venta (MACD)
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# ✅ Gráfico con flechas
plt.figure(figsize=(14, 6))
plt.plot(dados["Date"], dados["close"], label="Preço", color="black")
plt.plot(dados["Date"], dados["MM20"], label="MM20", linestyle="--", color="blue")
plt.plot(dados["Date"], dados["MM50"], label="MM50", linestyle="--", color="orange")

plt.scatter(dados.loc[dados["Compra"], "Date"], dados.loc[dados["Compra"], "close"],
            label="📈 Compra", marker="^", color="green", s=100)
plt.scatter(dados.loc[dados["Venda"], "Date"], dados.loc[dados["Venda"], "close"],
            label="📉 Venda", marker="v", color="red", s=100)

plt.title("USD/BRL - Sinais de Compra e Venda (Alpha Vantage)")
plt.xlabel("Data")
plt.ylabel("Preço")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9612\2194975088.py in <module>
#      13
#      14 # ✅ Leer datos como DataFrame
# ---> 15 dados = pd.read_csv(pd.compat.StringIO(res.text))
#      16 dados.rename(columns={'timestamp': 'Date'}, inplace=True)
#      17 dados["Date"] = pd.to_datetime(dados["Date"])
#
# AttributeError: module 'pandas.compat' has no attribute 'StringIO'

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD
from io import StringIO  # ✅ Corrección aquí

# Tu clave de API de Alpha Vantage
api_key = "CW8ZHIC5A9DKYDVQ"

# Endpoint de Alpha Vantage (intervalo de 5 minutos)
url = f"https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol=USD&to_symbol=BRL&interval=5min&apikey={api_key}&datatype=csv"

# Obtener los datos
res = requests.get(url)

# Leer CSV desde el texto de la respuesta
dados = pd.read_csv(StringIO(res.text))  # ✅ Corrección aquí
dados.rename(columns={"timestamp": "Date"}, inplace=True)
dados["Date"] = pd.to_datetime(dados["Date"])
dados.sort_values("Date", inplace=True)
dados.reset_index(drop=True, inplace=True)

# Calcular MACD
macd_calc = MACD(dados["close"], window_slow=26, window_fast=12, window_sign=9)
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()

# Sinais de compra/venda (MACD cruza a linha de sinal)
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# 📈 GRÁFICO com sinais e volume
plt.figure(figsize=(14, 8))

# Preço
plt.subplot(2, 1, 1)
plt.plot(dados["Date"], dados["close"], label="Preço", color="black")
plt.scatter(dados.loc[dados["Compra"], "Date"], dados.loc[dados["Compra"], "close"], label="▲ Compra", marker="^", color="green", s=100)
plt.scatter(dados.loc[dados["Venda"], "Date"], dados.loc[dados["Venda"], "close"], label="▼ Venda", marker="v", color="red", s=100)
plt.title("USD/BRL – Sinais de Compra e Venda (Alpha Vantage)")
plt.xlabel("Data")
plt.ylabel("Preço")
plt.legend()
plt.grid(True)

# Volume
plt.subplot(2, 1, 2)
plt.bar(dados["Date"], dados["volume"], color="gray", width=0.01)
plt.title("USD/BRL – Volume Negociado")
plt.xlabel("Data")
plt.ylabel("Volume")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# !pip install ta

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD
from io import StringIO  # ✅ Corrección aquí

# Tu clave de API de Alpha Vantage
api_key = "CW8ZHIC5A9DKYDVQ"

# Endpoint de Alpha Vantage (intervalo de 5 minutos)
url = f"https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol=USD&to_symbol=BRL&interval=5min&apikey={api_key}&datatype=csv"

# Obtener los datos
res = requests.get(url)

# Leer CSV desde el texto de la respuesta
dados = pd.read_csv(StringIO(res.text))  # ✅ Corrección aquí
dados.rename(columns={"timestamp": "Date"}, inplace=True)
dados["Date"] = pd.to_datetime(dados["Date"])
dados.sort_values("Date", inplace=True)
dados.reset_index(drop=True, inplace=True)

# Calcular MACD
macd_calc = MACD(dados["close"], window_slow=26, window_fast=12, window_sign=9)
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()

# Sinais de compra/venda (MACD cruza a linha de sinal)
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# 📈 GRÁFICO com sinais e volume
plt.figure(figsize=(14, 8))

# Preço
plt.subplot(2, 1, 1)
plt.plot(dados["Date"], dados["close"], label="Preço", color="black")
plt.scatter(dados.loc[dados["Compra"], "Date"], dados.loc[dados["Compra"], "close"], label="▲ Compra", marker="^", color="green", s=100)
plt.scatter(dados.loc[dados["Venda"], "Date"], dados.loc[dados["Venda"], "close"], label="▼ Venda", marker="v", color="red", s=100)
plt.title("USD/BRL – Sinais de Compra e Venda (Alpha Vantage)")
plt.xlabel("Data")
plt.ylabel("Preço")
plt.legend()
plt.grid(True)

# Volume
plt.subplot(2, 1, 2)
plt.bar(dados["Date"], dados["volume"], color="gray", width=0.01)
plt.title("USD/BRL – Volume Negociado")
plt.xlabel("Data")
plt.ylabel("Volume")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD
from io import StringIO  # ✅ Corrección aquí

# Tu clave de API de Alpha Vantage
api_key = "CW8ZHIC5A9DKYDVQ"

# Endpoint de Alpha Vantage (intervalo de 5 minutos)
url = f"https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol=USD&to_symbol=BRL&interval=5min&apikey={api_key}&datatype=csv"

# Obtener los datos
res = requests.get(url)

# Leer CSV desde el texto de la respuesta
dados = pd.read_csv(StringIO(res.text))  # ✅ Corrección aquí
dados.rename(columns={"timestamp": "Date"}, inplace=True)
dados["Date"] = pd.to_datetime(dados["Date"])
dados.sort_values("Date", inplace=True)
dados.reset_index(drop=True, inplace=True)

# Calcular MACD
macd_calc = MACD(dados["close"], window_slow=26, window_fast=12, window_sign=9)
dados["MACD"] = macd_calc.macd()
dados["MACD_Sinal"] = macd_calc.macd_signal()
dados["MACD_Histograma"] = macd_calc.macd_diff()

# Sinais de compra/venda (MACD cruza a linha de sinal)
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# 📈 GRÁFICO com sinais e volume
plt.figure(figsize=(14, 8))

# Preço
plt.subplot(2, 1, 1)
plt.plot(dados["Date"], dados["close"], label="Preço", color="black")
plt.scatter(dados.loc[dados["Compra"], "Date"], dados.loc[dados["Compra"], "close"], label="▲ Compra", marker="^", color="green", s=100)
plt.scatter(dados.loc[dados["Venda"], "Date"], dados.loc[dados["Venda"], "close"], label="▼ Venda", marker="v", color="red", s=100)
plt.title("USD/BRL – Sinais de Compra e Venda (Alpha Vantage)")
plt.xlabel("Data")
plt.ylabel("Preço")
plt.legend()
plt.grid(True)

# Volume
plt.subplot(2, 1, 2)
plt.bar(dados["Date"], dados["volume"], color="gray", width=0.01)
plt.title("USD/BRL – Volume Negociado")
plt.xlabel("Data")
plt.ylabel("Volume")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD
from io import StringIO

# 🔑 Tu clave de API
api_key = "CW8ZHIC5A9DKYDVQ"

# 🟦 Endpoint Alpha Vantage (USD/BRL, 5 min)
url = f"https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol=USD&to_symbol=BRL&interval=5min&apikey={api_key}&datatype=csv"

# 🔄 Obtener datos
res = requests.get(url)
datos = pd.read_csv(StringIO(res.text))

# 🧹 Limpieza
datos.rename(columns={'timestamp': 'Date', 'close': 'Close'}, inplace=True)
datos['Date'] = pd.to_datetime(datos['Date'])
datos.sort_values("Date", inplace=True)
datos.reset_index(drop=True, inplace=True)

# 📊 Calcular MACD
macd = MACD(close=datos["Close"], window_slow=26, window_fast=12, window_sign=9)
datos["MACD"] = macd.macd()
datos["MACD_Sinal"] = macd.macd_signal()
datos["MACD_Histograma"] = macd.macd_diff()

# 📌 Generar señales automáticas
datos["Compra"] = (datos["MACD"] > datos["MACD_Sinal"]) & (datos["MACD"].shift(1) <= datos["MACD_Sinal"].shift(1))
datos["Venda"] = (datos["MACD"] < datos["MACD_Sinal"]) & (datos["MACD"].shift(1) >= datos["MACD_Sinal"].shift(1))

# 📈 Gráfico de Precio con Señales
plt.figure(figsize=(14, 6))
plt.plot(datos["Date"], dados["Close"], label="Preço", color="black")
plt.scatter(datos.loc[datos["Compra"], "Date"], dados.loc[datos["Compra"], "Close"], label="▲ Compra", marker="^", color="green", s=100)
plt.scatter(datos.loc[datos["Venda"], "Date"], dados.loc[datos["Venda"], "Close"], label="▼ Venda", marker="v", color="red", s=100)
plt.title("USD/BRL - Sinais de Compra e Venda (MACD)")
plt.xlabel("Data")
plt.ylabel("Preço (R$)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 📉 Gráfico de Volume (simulado porque FX_INTRADAY no devuelve volume real)
plt.figure(figsize=(14, 2.5))
plt.bar(datos["Date"], range(len(datos)), color="gray", width=0.01)
plt.title("USD/BRL - Volume (Simulado)")
plt.xlabel("Data")
plt.ylabel("Volume (simulado)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD
from io import StringIO

api_key = "CW8ZHIC5A9DKYDVQ"

url = f"https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol=USD&to_symbol=BRL&interval=5min&apikey={api_key}&datatype=csv"
res = requests.get(url)

# Cargar datos
dados = pd.read_csv(StringIO(res.text))
print(dados.columns)  # 👀 Verifica los nombres reales

# Normalizar columnas por si tienen espacios ocultos
dados.columns = dados.columns.str.strip()

# Renombrar si las columnas existen
if "timestamp" in dados.columns:
    dados.rename(columns={'timestamp': 'Date'}, inplace=True)
if "close" in dados.columns:
    dados.rename(columns={'close': 'Close'}, inplace=True)

# Verifica si 'Date' fue creado
if 'Date' not in dados.columns:
    raise ValueError("❌ No se encontró la columna 'Date'. Revisa los nombres originales.")

# Procesamiento
dados['Date'] = pd.to_datetime(dados['Date'])
dados.sort_values("Date", inplace=True)
dados.reset_index(drop=True, inplace=True)

# Calcular MACD
macd = MACD(close=dados["Close"], window_slow=26, window_fast=12, window_sign=9)
dados["MACD"] = macd.macd()
dados["MACD_Sinal"] = macd.macd_signal()
dados["MACD_Histograma"] = macd.macd_diff()

# Señales
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# Gráfico de precio + señales
plt.figure(figsize=(14, 6))
plt.plot(dados["Date"], dados["Close"], label="Preço", color="black")
plt.scatter(dados.loc[dados["Compra"], "Date"], dados.loc[dados["Compra"], "Close"], label="▲ Compra", color="green", marker="^", s=100)
plt.scatter(dados.loc[dados["Venda"], "Date"], dados.loc[dados["Venda"], "Close"], label="▼ Venda", color="red", marker="v", s=100)
plt.title("USD/BRL - Sinais de Compra e Venda (MACD)")
plt.xlabel("Data")
plt.ylabel("Preço (R$)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Gráfico de volume (simulado)
plt.figure(figsize=(14, 3))
plt.bar(dados["Date"], range(len(dados)), color="gray", width=0.01)
plt.title("USD/BRL - Volume (simulado)")
plt.xlabel("Data")
plt.ylabel("Volume")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Index(['{'], dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12660\1267640496.py in <module>
#      25 # Verifica si 'Date' fue creado
#      26 if 'Date' not in dados.columns:
# ---> 27     raise ValueError("❌ No se encontró la columna 'Date'. Revisa los nombres originales.")
#      28
#      29 # Procesamiento
#
# ValueError: ❌ No se encontró la columna 'Date'. Revisa los nombres originales.

# %%
print(res.text)
# Out:
# {
#     "Information": "Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints"
# }

# %%
# !pip install ta

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from ta.trend import MACD
from ta.momentum import RSIIndicator
from io import StringIO

# 🔑 Tu clave API de Alpha Vantage
api_key = "CW8ZHIC5A9DKYDVQ"

# 📦 Endpoint gratuito FX_DAILY
url = f"https://www.alphavantage.co/query?function=FX_DAILY&from_symbol=USD&to_symbol=BRL&apikey={api_key}&datatype=csv"

# 📥 Obtener datos
res = requests.get(url)
dados = pd.read_csv(StringIO(res.text))

# 🧼 Limpiar y preparar
dados.rename(columns={"timestamp": "Date", "close": "Close"}, inplace=True)
dados["Date"] = pd.to_datetime(dados["Date"])
dados.sort_values("Date", inplace=True)
dados.reset_index(drop=True, inplace=True)

# 📈 Indicadores técnicos
dados["MM20"] = dados["Close"].rolling(window=20).mean()
dados["MM50"] = dados["Close"].rolling(window=50).mean()

macd = MACD(close=dados["Close"], window_slow=26, window_fast=12, window_sign=9)
dados["MACD"] = macd.macd()
dados["MACD_Sinal"] = macd.macd_signal()
dados["MACD_Histograma"] = macd.macd_diff()

rsi = RSIIndicator(close=dados["Close"], window=14)
dados["RSI"] = rsi.rsi()

# 📌 Señales automáticas
dados["Compra"] = (dados["MACD"] > dados["MACD_Sinal"]) & (dados["MACD"].shift(1) <= dados["MACD_Sinal"].shift(1))
dados["Venda"] = (dados["MACD"] < dados["MACD_Sinal"]) & (dados["MACD"].shift(1) >= dados["MACD_Sinal"].shift(1))

# 📊 Gráfico con señales
plt.figure(figsize=(14, 6))
plt.plot(dados["Date"], dados["Close"], label="Preço", color="black")
plt.plot(dados["Date"], dados["MM20"], label="MM20", linestyle="--", color="blue")
plt.plot(dados["Date"], dados["MM50"], label="MM50", linestyle="--", color="orange")
plt.scatter(dados.loc[dados["Compra"], "Date"], dados.loc[dados["Compra"], "Close"],
            label="▲ Compra", marker="^", color="green", s=100)
plt.scatter(dados.loc[dados["Venda"], "Date"], dados.loc[dados["Venda"], "Close"],
            label="▼ Venda", marker="v", color="red", s=100)

plt.title("USD/BRL - Sinais de Compra e Venda com MACD")
plt.xlabel("Data")
plt.ylabel("Preço (R$)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
